# %%
# Downloading and preparing stock data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

start_date = '2010-01-01'
end_date = '2020-01-01'
ticker = 'INVE-B.ST'
df = yf.download(ticker,start_date,end_date)

df.reset_index(inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
X = np.array(df.index).reshape(-1,1)
y = df['Adj Close']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, train_size=0.75)

linreg_model = LinearRegression()
linreg_model.fit(X_train, y_train)

predicted_price = linreg_model.predict(X_test)
predicted_price = pd.DataFrame(predicted_price,index=y_test.index, columns= ['Price'])

# %%
# Plot the stock data
plt.plot(df['Date'], df['Close'], label='Stock Price')

# Use a prediction model to generate future values for the stock price
future_dates = pd.date_range(df['Date'].iloc[-1], periods=365, freq='D')

future_prices = linreg_model.predict(future_dates)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 7
#       4 # Use a prediction model to generate future values for the stock price
#       5 future_dates = pd.date_range(df['Date'].iloc[-1], periods=365, freq='D')
# ----> 7 future_prices = linreg_model.predict(future_dates)
#
# File c:\Users\Henke\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:355, in LinearModel.predict(self, X)
#     341 def predict(self, X):
#     342     """
#     343     Predict using the linear model.
#     344
#    (...)
#     353         Returns predicted values.
#     354     """
# --> 355     return self._decision_function(X)
#
# File c:\Users\Henke\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:338, in LinearModel._decision_function(self, X)
#     335 def _decision_function(self, X):
#     336     check_is_fitted(self)
# --> 338     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     339     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File c:\Users\Henke\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     533     raise ValueError("Validation should be done on X, y or both.")
#     534 elif not no_val_X and no_val_y:
# --> 535     X = check_array(X, input_name="X", **check_params)
#     536     out = X
#     537 elif no_val_X and not no_val_y:
#
# File c:\Users\Henke\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:900, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     898     # If input is 1D raise error
#     899     if array.ndim == 1:
# --> 900         raise ValueError(
#     901             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     902             "Reshape your data either using array.reshape(-1, 1) if "
#     903             "your data has a single feature or array.reshape(1, -1) "
#     904             "if it contains a single sample.".format(array)
#     905         )
#     907 if dtype_numeric and array.dtype.kind in "USV":
#     908     raise ValueError(
#     909         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     910         "Convert your data to numeric values explicitly instead."
#     911     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[Timestamp('2019-12-30 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2019-12-31 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-01 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-02 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-03 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-04 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-05 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-06 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-07 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-08 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-09 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-10 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-11 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-12 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-13 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-14 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-15 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-16 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-17 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-18 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-19 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-20 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-21 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-22 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-23 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-24 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-25 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-26 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-27 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-28 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-29 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-30 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-01-31 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-01 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-02 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-03 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-04 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-05 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-06 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-07 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-08 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-09 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-10 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-11 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-12 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-13 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-14 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-15 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-16 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-17 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-18 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-19 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-20 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-21 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-22 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-23 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-24 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-25 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-26 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-27 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-28 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-02-29 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-01 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-02 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-03 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-04 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-05 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-06 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-07 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-08 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-09 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-10 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-11 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-12 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-13 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-14 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-15 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-16 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-17 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-18 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-19 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-20 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-21 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-22 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-23 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-24 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-25 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-26 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-27 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-28 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-29 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-30 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-03-31 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-01 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-02 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-03 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-04 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-05 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-06 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-07 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-08 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-09 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-10 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-11 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-12 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-13 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-14 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-15 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-16 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-17 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-18 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-19 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-20 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-21 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-22 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-23 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-24 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-25 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-26 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-27 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-28 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-29 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-04-30 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-01 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-02 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-03 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-04 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-05 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-06 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-07 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-08 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-09 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-10 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-11 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-12 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-13 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-14 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-15 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-16 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-17 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-18 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-19 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-20 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-21 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-22 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-23 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-24 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-25 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-26 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-27 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-28 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-29 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-30 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-05-31 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-01 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-02 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-03 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-04 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-05 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-06 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-07 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-08 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-09 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-10 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-11 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-12 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-13 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-14 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-15 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-16 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-17 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-18 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-19 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-20 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-21 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-22 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-23 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-24 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-25 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-26 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-27 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-28 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-29 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-06-30 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-01 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-02 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-03 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-04 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-05 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-06 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-07 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-08 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-09 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-10 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-11 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-12 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-13 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-14 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-15 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-16 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-17 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-18 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-19 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-20 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-21 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-22 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-23 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-24 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-25 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-26 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-27 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-28 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-29 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-30 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-07-31 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-01 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-02 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-03 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-04 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-05 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-06 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-07 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-08 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-09 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-10 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-11 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-12 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-13 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-14 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-15 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-16 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-17 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-18 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-19 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-20 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-21 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-22 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-23 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-24 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-25 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-26 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-27 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-28 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-29 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-30 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-08-31 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-01 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-02 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-03 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-04 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-05 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-06 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-07 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-08 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-09 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-10 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-11 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-12 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-13 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-14 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-15 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-16 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-17 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-18 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-19 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-20 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-21 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-22 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-23 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-24 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-25 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-26 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-27 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-28 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-29 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-09-30 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-01 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-02 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-03 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-04 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-05 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-06 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-07 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-08 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-09 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-10 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-11 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-12 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-13 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-14 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-15 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-16 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-17 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-18 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-19 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-20 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-21 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-22 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-23 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-24 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-25 00:00:00+0200', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-26 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-27 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-28 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-29 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-30 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-10-31 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-01 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-02 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-03 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-04 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-05 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-06 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-07 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-08 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-09 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-10 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-11 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-12 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-13 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-14 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-15 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-16 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-17 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-18 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-19 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-20 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-21 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-22 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-23 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-24 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-25 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-26 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-27 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-28 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-29 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-11-30 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-01 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-02 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-03 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-04 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-05 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-06 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-07 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-08 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-09 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-10 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-11 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-12 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-13 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-14 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-15 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-16 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-17 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-18 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-19 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-20 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-21 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-22 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-23 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-24 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-25 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-26 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-27 00:00:00+0100', tz='Europe/Stockholm', freq='D')
#  Timestamp('2020-12-28 00:00:00+0100', tz='Europe/Stockholm', freq='D')].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
# Add the predicted values to the dataframe and plot the line
df_future = pd.DataFrame({'Date': future_dates, 'Close': future_prices})
plt.plot(df_future['Date'], df_future['Close'], label='Predicted Price')

# Show the graph
plt.legend()
plt.show()
